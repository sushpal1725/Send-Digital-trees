# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt 
# %matplotlib inline

all_free_tree = pd.read_csv('all_free_tree.csv', delimiter = ' ', names = ['day', 'my_date', 'user_id', 'event_type'])

daily_free = all_free_tree.groupby('my_date').count()
daily_free.plot()

dailyfree_trees = daily_free.reset_index(drop = True).event_type

x = dailyfree_trees .index
y = dailyfree_trees .values

coefs = np.polyfit(x, y, 1)
predict = np.poly1d(coefs)

from sklearn.metrics import r2_score
r2_score(y, predict(x))

x_test = np.linspace(0, 186)
y_pred = predict(x_test[:, None])
plt.scatter(x, y)
plt.plot(x_test, y_pred, c = 'r')
plt.show()

print(predict(186 + 28))

coefs = np.polyfit(x, y, 2)
predict = np.poly1d(coefs)

x_test = np.linspace(0, 186)
y_pred = predict(x_test[:, None])
plt.scatter(x, y)
plt.plot(x_test, y_pred, c = 'r')
plt.show()

print(predict(186 + 28))
    
coefs = np.polyfit(x, y, 3)
predict = np.poly1d(coefs)

x_test = np.linspace(0, 186)
y_pred = predict(x_test[:, None])
plt.scatter(x, y)
plt.plot(x_test, y_pred, c = 'r')
plt.show()

print(predict(186 + 28))

coefs = np.polyfit(x, y, 4)
predict = np.poly1d(coefs)

x_test = np.linspace(0, 186)
y_pred = predict(x_test[:, None])
plt.scatter(x, y)
plt.plot(x_test, y_pred, c = 'r')
plt.show()

print(predict(186 + 28))

coefs = np.polyfit(x, y, 5)
predict = np.poly1d(coefs)

x_test = np.linspace(0, 186)
y_pred = predict(x_test[:, None])
plt.scatter(x, y)
plt.plot(x_test, y_pred, c = 'r')
plt.show()

print(predict(186 + 28))
# Out:
# /usr/lib/python3/dist-packages/pandas/plotting/_core.py:394: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# 8967.707258341932
# 13516.272907440576
# 19177.86969806614
# 24030.155329831836
# 27369.112074845372
